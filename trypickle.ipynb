# %%
import pandas as pd
import pickle
import numpy as np

# %%
x_train = pd.read_csv("train_data.csv")
x_test = pd.read_csv("test_data.csv")

# %%
x_train
# Out:
#       Unnamed: 0  CashbackAmount  Tenure  CityTier  WarehouseToHome  \
# 0           1420          144.24     4.0         1             14.0
# 1           1344          144.04     7.0         1             14.0
# 2           4055          135.91     1.0         3             31.0
# 3            588          122.70     0.0         1              6.0
# 4           4539          291.59    29.0         1              9.0
# ...          ...             ...     ...       ...              ...
# 4175         959          170.83     7.0         3              6.0
# 4176        5593          174.07     1.0         3             15.0
# 4177        4258          263.72    31.0         3             17.0
# 4178         251          149.36    24.0         3             20.0
# 4179        5555          181.17     1.0         3             33.0
#
#       NumberOfDeviceRegistered  SatisfactionScore  NumberOfAddress  Complain  \
# ...

# %%
x_train.drop('Unnamed: 0', axis=1, inplace=True)
x_test.drop('Unnamed: 0', axis=1, inplace=True)

# %% [markdown]
# # Open Model

# %% [markdown]
# ### Using Train Data

# %%
pickled_model = pickle.load(open('Churn_rf.pkl', 'rb'))
y_predict = pickled_model.predict(x_train)
result = pd.DataFrame(y_predict, columns=['Churn'])
result.value_counts()
# Out:
# Churn
# 0        3465
# 1         715
# dtype: int64

# %% [markdown]
# ### Using Test Data

# %%
pickled_model = pickle.load(open('Churn_rf.pkl', 'rb'))
y_predict = pickled_model.predict(x_test)
result = pd.DataFrame(y_predict, columns=['Churn'])
result.value_counts()
# Out:
# Churn
# 0        867
# 1        179
# dtype: int64
